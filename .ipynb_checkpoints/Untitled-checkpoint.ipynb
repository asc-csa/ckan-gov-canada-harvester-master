# %%
# encoding: utf-8
import urllib2
import urllib
import json
import pprint
import pandas as pd
import numpy as np
import re
import logging

test_dataset = {
    'collection': 'publication',
    'title_translated': {
        'en': 'englishtiiitlle',
        'fr': 'frtiiiitle'
    },
    'name': 'hellobo',
    'owner_org': 'csa',
    'contributor': {
        'fr': '',
        'en': ''
    },
    'notes_translated': {
        'en': 'ENGLISH NOTES',
        'fr': 'FREEENCH NOTES'
    },
    'keywords': {
        'fr': [
            'Agence spatiale canadienne',
            'ASC',
            'Rendement',
            'Programme spatial canadien',
            'États financiers'
        ],
        'en': [
            'Canadian Space Agency',
            'CSA',
            'Performance management',
            'Canadian Space Program',
            'Financial statements'
        ]
    },
    
    'subject': [
        'economics_and_industry',
        'government_and_politics'
    ],
    
    'audience': [
        'general_public',
        'government',
        'media'
    ],
    
    'place_of_publication': [
        '2458'
    ],
    'imso_approval': 'true',
    'restrictions': 'unrestricted',
    'jurisdiction': 'federal',
    'ready_to_publish': 'true',
    "license_id": "ca-ogl-lgo",
    'portal_release_date': '2017-03-14',
    'time_period_coverage_start': '2015-04-01 00:00:00',
    'time_period_coverage_end': '2016-03-31 00:00:00',
    'frequency': 'not_planned',
    'date_published': '2016-11-21 00:00:00',
    'version':  '1.0',
    'language_support': 'english',
    'language_support_specify': 'No French',
    'data_steward': 'Cooper Ang',
    'manager_or_supervisor': 'Manager',
    'diids_no': 'OD1231343',
    'directorate': 'communications',
    'dataset_status': 'completed_form_od',
    'division': 'expl_space_exploration_development',
    'data_owner': 'csa',
    'data_owner_specify': 'none',
    'security_classification': 'protected_a',
    'registered_on_open_data_site': 'True',
    'data_publicly_availible_within_another_site': 'False',
    'eligible_for_release': 'True',
    'format_of_source_data_details': 'xls fs',
    'format_of_source_data': 'xls',
    'size': '340'
}



data_string = urllib.quote(json.dumps(test_dataset))
# We'll use the package_create function to create a new dataset.
request = urllib2.Request(
    'http://127.0.0.1:5000/api/action/package_create')

# Creating a dataset requires an authorization header.
# Replace *** with your API key, from your user account on the CKAN site
# that you're creating the dataset on.
request.add_header('Authorization', 'a1fdb004-aad7-4bd2-acc1-a0971ee40962')

# Make the HTTP request.
response = urllib2.urlopen(request, data_string)
assert response.code == 200

# Use the json module to load CKAN's response into a dictionary.
response_dict = json.loads(response.read())

if response_dict['success'] is False:
    logging.error('Dataset failed to upload')

# package_create returns the created package as its result.
created_package = response_dict['result']
pprint.pprint(created_package)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-c6b0fd248900> in <module>()
#      99
#     100 # Make the HTTP request.
# --> 101 response = urllib2.urlopen(request, data_string)
#     102 assert response.code == 200
#     103
#
# /usr/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /usr/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     433         for processor in self.process_response.get(protocol, []):
#     434             meth = getattr(processor, meth_name)
# --> 435             response = meth(req, response)
#     436
#     437         return response
#
# /usr/lib/python2.7/urllib2.pyc in http_response(self, request, response)
# ...
