# %% [markdown]
# ## Data Cleaning datasets from gov canada

# %%
# -*- coding: utf-8 -*-
import json
import pprint
import re
import logging

# %% [markdown]
# Import the datasets as a list of dictionaries, each one being a dataset

# %%
with open('gov_canada_datasets_raw.json', 'r') as f:
    datasets = json.load(f)

# %%
datasets[0][u'result']
# Out:
# {u'association_type': [],
#  u'audience': [u'general_public', u'scientists', u'students'],
#  u'author': None,
#  u'author_email': None,
#  u'collection': u'primary',
#  u'contributor': {u'en': u'', u'fr': u''},
#  u'creator': u'',
#  u'creator_user_id': u'4cfa9a9c-1d95-40eb-86f9-bc0c8ec45d1f',
#  u'data_series_issue_identification': {u'en': u'', u'fr': u''},
#  u'data_series_name': {u'en': u'', u'fr': u''},
#  u'date_published': u'2018-08-06 00:00:00',
#  u'digital_object_identifier': u'',
#  u'display_flags': [],
#  u'frequency': u'as_needed',
#  u'geographic_region': [],
#  u'groups': [],
#  u'id': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#  u'imso_approval': u'true',
#  u'isopen': False,
#  u'jurisdiction': u'federal',
#  u'keywords': {u'en': [u'Stratospheric Balloon',
#    u'STRATOS',
#    u'Canadian Space Agency',
#    u'CSA',
#    u'Telemetry',
#    u'Strato-Science 2018',
#    u'Timmins',
#    u'Ontario',
#    u'Picutres',
#    u'Stratosphere',
#    u'Sub-Systems',
#    u'PRIMS',
#    u'Payload',
#    u'Sensor',
#    u'Mass Memory'],
#   u'fr': [u'Ballon stratosph\xe9rique',
#    u'STRATOS',
#    u'Agence spatiale canadienne',
#    u'ASC',
#    u't\xe9l\xe9m\xe9trie',
#    u'Strato-Science 2018',
#    u'Timmins',
#    u'Ontario',
#    u'Images',
#    u'Stratosph\xe8re',
#    u'Sous-syst\xe8mes',
#    u'PRISM',
#    u'charge utile',
#    u'capteurs',
#    u'm\xe9moire de masse']},
#  u'license_id': u'ca-ogl-lgo',
#  u'license_title': u'Open Government Licence - Canada',
#  u'license_url': u'http://open.canada.ca/en/open-government-licence-canada',
#  u'maintainer': None,
#  u'maintainer_email': u'open-ouvert@tbs-sct.gc.ca',
#  u'metadata_contact': {},
#  u'metadata_created': u'2019-10-22T18:00:30.425128',
#  u'metadata_modified': u'2019-10-22T18:00:30.425137',
#  u'name': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#  u'notes': u"This dataset contains the telemetry data obtained from the different subsystems during the Strato-Science 2018 campaign of the Canadian Space Agency (CSA) which took place in Timmins, Ontario, Canada between August 6 and 26, 2018. (For more information on this campaign : http://www.asc-csa.gc.ca/fra/sciences/ballons/campagne-2018.asp.)\r\n\r\nThe data was collected during the flight named NUMBUS-5/FAST. These data originate mainly from Payload Remote Interface, Sensor Suite and Mass Memory Subsystem (PRISM). This multi-purpose electronics box provides onboard Ethernet ports for payloads and offer various services to users, such as real-time localization and attitude, during the entire flight. The instrument also monitors other components onboard the gondola, the platform carrying the experiments and payloads. This instrument is an improved version of a technology initially developed by students from \xc9cole de technologie sup\xe9rieure, and further advanced by the CSA. \r\nData from Power Distribution Unit and Battery are also available. This modular subsystem consists of a set of Li-ion batteries and a power distribution unit. It was developed by CSA to support payloads power requirements during STRATOS flights.\r\n\r\nSTRATOS, the CSA\u2019s stratospheric balloon program, was created in 2012 through the CSA's collaboration with France's space agency, CNES. This program gives Canadian universities and businesses the opportunity to test and validate new technologies and to perform scientific experiments at an altitude where only balloons can be operated. (http://www.asc-csa.gc.ca/eng/sciences/balloons/default.asp)",
#  u'notes_translated': {u'en': u"This dataset contains the telemetry data obtained from the different subsystems during the Strato-Science 2018 campaign of the Canadian Space Agency (CSA) which took place in Timmins, Ontario, Canada between August 6 and 26, 2018. (For more information on this campaign : http://www.asc-csa.gc.ca/fra/sciences/ballons/campagne-2018.asp.)\r\n\r\nThe data was collected during the flight named NUMBUS-5/FAST. These data originate mainly from Payload Remote Interface, Sensor Suite and Mass Memory Subsystem (PRISM). This multi-purpose electronics box provides onboard Ethernet ports for payloads and offer various services to users, such as real-time localization and attitude, during the entire flight. The instrument also monitors other components onboard the gondola, the platform carrying the experiments and payloads. This instrument is an improved version of a technology initially developed by students from \xc9cole de technologie sup\xe9rieure, and further advanced by the CSA. \r\nData from Power Distribution Unit and Battery are also available. This modular subsystem consists of a set of Li-ion batteries and a power distribution unit. It was developed by CSA to support payloads power requirements during STRATOS flights.\r\n\r\nSTRATOS, the CSA\u2019s stratospheric balloon program, was created in 2012 through the CSA's collaboration with France's space agency, CNES. This program gives Canadian universities and businesses the opportunity to test and validate new technologies and to perform scientific experiments at an altitude where only balloons can be operated. (http://www.asc-csa.gc.ca/eng/sciences/balloons/default.asp)",
#   u'fr': u"Cet ensemble de donn\xe9es contient les donn\xe9es de t\xe9l\xe9mesure obtenues des diff\xe9rents sous-syst\xe8mes pendant la Campagne Strato-Science 2018 de l\u2019Agence spatiale canadienne (ASC), qui s\u2019est tenue \xe0 Timmins, Ontario, Canada entre le 6 et le 26 ao\xfbt 2018. (Pour plus d\u2019information sur cette campagne : http://www.asc-csa.gc.ca/fra/sciences/ballons/campagne-2018.asp.)\r\n\r\nLes donn\xe9es ont \xe9t\xe9 collect\xe9es durant le vol nomm\xe9 NIMBUS-5/FAST. Ces donn\xe9es proviennent principalement du Sous-syst\xe8me d\u2019interface de charge utile \xe0 distance, suite de capteurs et m\xe9moire de masse, nomm\xe9e PRISM (Payload Remote Interface, Sensor Suite and Mass Memory Subsystem).  Cette bo\xeete \xe9lectronique polyvalente fournit des ports Ethernet embarqu\xe9s pour les charges utiles et offre divers services aux utilisateurs, tels que la localisation et l'attitude en temps r\xe9el, pendant tout le vol. De plus, l'instrument surveille, au moyen de divers capteurs, d'autres composants \xe0 bord de la nacelle, soit la plateforme qui transporte les charges utiles. Cet instrument est une version am\xe9lior\xe9e d'une technologie mise au point par un groupe d'\xe9tudiants de l'\xc9cole de technologie sup\xe9rieure puis am\xe9lior\xe9e par l'ASC. \r\nDes donn\xe9es provenant de l\u2019Unit\xe9 de distribution d\u2019alimentation et batterie sont \xe9galement disponibles. Ce sous-syst\xe8me modulaire se compose d'un ensemble de batteries lithium-ion et d'une unit\xe9 de distribution d'\xe9nergie. Il a \xe9t\xe9 d\xe9velopp\xe9 par l'ASC pour les vols STRATOS afin de fournir l'\xe9nergie n\xe9cessaire aux charges utiles.\r\n\r\nSTRATOS, le programme de ballons stratosph\xe9riques de l'ASC, a \xe9t\xe9 cr\xe9\xe9 en 2012 gr\xe2ce \xe0 une collaboration avec le Centre national d'\xe9tudes spatiales (CNES). Ce programme offre aux universit\xe9s et aux entreprises canadiennes la possibilit\xe9 de tester et de valider de nouvelles technologies ainsi que de r\xe9aliser des exp\xe9riences scientifiques \xe0 une altitude o\xf9 seuls les ballons peuvent \xe9voluer. (http://www.asc-csa.gc.ca/fra/sciences/ballons/default.asp)"},
#  u'num_resources': 6,
#  u'num_tags': 0,
#  u'org_section': {u'en': u'', u'fr': u''},
#  u'org_title_at_publication': {u'en': u'Canadian Space Agency',
#   u'fr': u'Agence spatiale canadienne'},
#  u'organization': {u'approval_status': u'approved',
#   u'created': u'2016-09-23T17:25:16.335185',
#   u'description': u'',
#   u'id': u'95F65CF9-ED6A-4630-9C1A-8339FDB15CF0',
#   u'image_url': u'',
#   u'is_organization': True,
#   u'name': u'csa-asc',
#   u'revision_id': u'759a4b1f-4e49-4125-94ed-8e9da70ded08',
#   u'state': u'active',
#   u'title': u'Canadian Space Agency | Agence spatiale canadienne',
#   u'type': u'organization'},
#  u'owner_org': u'95F65CF9-ED6A-4630-9C1A-8339FDB15CF0',
#  u'place_of_publication': [],
#  u'portal_release_date': u'2019-10-22',
#  u'position_name': {},
#  u'private': False,
#  u'program_page_url': {u'en': u'http://asc-csa.gc.ca/eng/sciences/balloons/campaign-2018.asp',
#   u'fr': u'http://asc-csa.gc.ca/fra/sciences/ballons/campagne-2018.asp'},
#  u'ready_to_publish': u'true',
#  u'relationships_as_object': [],
#  u'relationships_as_subject': [],
#  u'resources': [{u'cache_last_updated': None,
#    u'cache_url': None,
#    u'character_set': u'',
#    u'created': u'2019-10-22T18:00:32.805715',
#    u'data_quality': [],
#    u'datastore_active': False,
#    u'date_published': u'',
#    u'description': u'',
#    u'format': u'PDF',
#    u'hash': u'',
#    u'id': u'd3b3a120-5079-4f71-8684-47c1c7667e86',
#    u'language': [u'fr'],
#    u'last_modified': None,
#    u'mimetype': None,
#    u'mimetype_inner': None,
#    u'name': u'Stratos PRISM: StratoScience2018 Nimbus-5 Post-Launch Telemetry Data Analysis',
#    u'name_translated': {u'en': u'Stratos PRISM: StratoScience2018 Nimbus-5 Post-Launch Telemetry Data Analysis',
#     u'fr': u'PRISM pour Stratos: Strat-Science 2018 Analyse des donn\xe9es de t\xe9l\xe9m\xe9trie apr\xe8s le lancement de Nimbus-5'},
#    u'package_id': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#    u'position': 0,
#    u'related_relationship': u'',
#    u'related_type': u'',
#    u'resource_type': u'guide',
#    u'revision_id': u'8b8282b5-d13e-4dfb-a8df-161651159fc5',
#    u'size': u'2466000',
#    u'state': u'active',
#    u'unique_identifier': u'',
#    u'url': u'ftp://ftp.asc-csa.gc.ca/users/OpenData_DonneesOuvertes/pub/STRATOS%202018/csa_stratos_science_2018_prism_data_IR%20-%20fr.pdf',
#    u'url_type': None},
#   {u'cache_last_updated': None,
#    u'cache_url': None,
#    u'character_set': u'',
#    u'created': u'2019-10-22T18:00:32.805723',
#    u'data_quality': [],
#    u'datastore_active': False,
#    u'date_published': u'',
#    u'description': u'',
#    u'format': u'PDF',
#    u'hash': u'',
#    u'id': u'5f80354e-3a7d-450a-85d9-4cdf79835ec0',
#    u'language': [u'en'],
#    u'last_modified': None,
#    u'mimetype': None,
#    u'mimetype_inner': None,
#    u'name': u'Stratos PRISM: StratoScience2018 Nimbus-5 Post-Launch Telemetry Data Analysis',
#    u'name_translated': {u'en': u'Stratos PRISM: StratoScience2018 Nimbus-5 Post-Launch Telemetry Data Analysis',
#     u'fr': u'PRISM pour Stratos: Strat-Science 2018 Analyse des donn\xe9es de t\xe9l\xe9m\xe9trie apr\xe8s le lancement de Nimbus-5'},
#    u'package_id': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#    u'position': 1,
#    u'resource_type': u'guide',
#    u'revision_id': u'8b8282b5-d13e-4dfb-a8df-161651159fc5',
#    u'size': u'2466000',
#    u'state': u'active',
#    u'unique_identifier': u'',
#    u'url': u'ftp://ftp.asc-csa.gc.ca/users/OpenData_DonneesOuvertes/pub/STRATOS%202018/csa_stratos_science_2018_prism_data_IR.pdf',
#    u'url_type': None},
#   {u'cache_last_updated': None,
#    u'cache_url': None,
#    u'character_set': u'',
#    u'created': u'2019-10-22T18:00:32.805726',
#    u'data_quality': [],
#    u'datastore_active': False,
#    u'date_published': u'2019-10-21',
#    u'description': u'',
#    u'format': u'CSV',
#    u'hash': u'',
#    u'id': u'ee5d7ac1-0212-4e48-9a1d-b3af5b1e92ca',
#    u'language': [u'zxx'],
#    u'last_modified': None,
#    u'mimetype': None,
#    u'mimetype_inner': None,
#    u'name': u'Strato-Science 2018 campaign - Stratospheric Balloon Flight - Canadian Space Agency (CSA) Stratos Telemetry Subsystem - Dataset',
#    u'name_translated': {u'en': u'Strato-Science 2018 campaign - Stratospheric Balloon Flight - Canadian Space Agency (CSA) Stratos Telemetry Subsystem - Dataset',
#     u'fr': u'Campagne Strato-Science 2018 - Vol de ballons stratosph\xe9riques - Donn\xe9es des sous-syst\xe8mes de t\xe9l\xe9m\xe9trie de l\u2019Agence spatiale canadienne (ASC) - Ensemble de donn\xe9es'},
#    u'package_id': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#    u'position': 2,
#    u'related_relationship': u'',
#    u'related_type': u'',
#    u'resource_type': u'dataset',
#    u'revision_id': u'8b8282b5-d13e-4dfb-a8df-161651159fc5',
#    u'size': u'1417339207',
#    u'state': u'active',
#    u'unique_identifier': u'',
#    u'url': u'ftp://ftp.asc-csa.gc.ca/users/OpenData_DonneesOuvertes/pub/STRATOS%202018/',
#    u'url_type': None},
#   {u'cache_last_updated': None,
#    u'cache_url': None,
#    u'character_set': u'',
#    u'created': u'2019-10-22T18:00:32.805729',
#    u'data_quality': [],
#    u'datastore_active': False,
#    u'date_published': u'2019-10-21',
#    u'description': u'',
#    u'format': u'JPG',
#    u'hash': u'',
#    u'id': u'7a41ef44-f870-4433-83c3-0aa3830ef836',
#    u'language': [u'zxx'],
#    u'last_modified': None,
#    u'mimetype': None,
#    u'mimetype_inner': None,
#    u'name': u'Pictures of the horizon - Strato-Science 2018',
#    u'name_translated': {u'en': u'Pictures of the horizon - Strato-Science 2018',
#     u'fr': u"Images de l'horizon \u2013 Strato-Science 2018"},
#    u'package_id': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#    u'position': 3,
#    u'related_relationship': u'',
#    u'related_type': u'',
#    u'resource_type': u'dataset',
#    u'revision_id': u'8b8282b5-d13e-4dfb-a8df-161651159fc5',
#    u'size': u'18100000',
#    u'state': u'active',
#    u'unique_identifier': u'',
#    u'url': u'ftp://ftp.asc-csa.gc.ca/users/OpenData_DonneesOuvertes/pub/STRATOS%202018/CDH/CAM2-HOR/',
#    u'url_type': None},
#   {u'cache_last_updated': None,
#    u'cache_url': None,
#    u'character_set': u'',
#    u'created': u'2019-10-22T18:00:32.805732',
#    u'data_quality': [],
#    u'datastore_active': False,
#    u'date_published': u'2019-10-21',
#    u'description': u'',
#    u'format': u'JPG',
#    u'hash': u'',
#    u'id': u'197fcdd4-d256-47e9-966b-58ca330b519f',
#    u'language': [u'zxx'],
#    u'last_modified': None,
#    u'mimetype': None,
#    u'mimetype_inner': None,
#    u'name': u'Pictures straight down (nadir) - Strato-Science 2018',
#    u'name_translated': {u'en': u'Pictures straight down (nadir) - Strato-Science 2018',
#     u'fr': u'Images vers le bas (nadir) - Strato-Science 2018'},
#    u'package_id': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#    u'position': 4,
#    u'related_relationship': u'',
#    u'related_type': u'',
#    u'resource_type': u'dataset',
#    u'revision_id': u'8b8282b5-d13e-4dfb-a8df-161651159fc5',
#    u'size': u'479000000',
#    u'state': u'active',
#    u'unique_identifier': u'',
#    u'url': u'ftp://ftp.asc-csa.gc.ca/users/OpenData_DonneesOuvertes/pub/STRATOS%202018/CDH/CAM1-NADIR/',
#    u'url_type': None},
#   {u'cache_last_updated': None,
#    u'cache_url': None,
#    u'character_set': u'',
#    u'created': u'2019-10-22T18:00:32.805734',
#    u'data_quality': [],
#    u'datastore_active': False,
#    u'date_published': u'2019-10-21',
#    u'description': u'',
#    u'format': u'TXT',
#    u'hash': u'',
#    u'id': u'51663c8c-c1e9-48d8-8994-4a4e40710516',
#    u'language': [u'zxx'],
#    u'last_modified': None,
#    u'mimetype': None,
#    u'mimetype_inner': None,
#    u'name': u'Strato-Science 2018 campaign - Stratospheric Balloon Flight - Canadian Space Agency (CSA) Stratos Telemetry Subsystem - Dataset',
#    u'name_translated': {u'en': u'Strato-Science 2018 campaign - Stratospheric Balloon Flight - Canadian Space Agency (CSA) Stratos Telemetry Subsystem - Dataset',
#     u'fr': u'Campagne Strato-Science 2018 - Vol de ballons stratosph\xe9riques - Donn\xe9es des sous-syst\xe8mes de t\xe9l\xe9m\xe9trie de l\u2019Agence spatiale canadienne (ASC) - Ensemble de donn\xe9es'},
#    u'package_id': u'a27cfbe9-db7e-46f0-b5b8-63190cc91d55',
#    u'position': 5,
#    u'related_relationship': u'',
#    u'related_type': u'',
#    u'resource_type': u'dataset',
#    u'revision_id': u'8b8282b5-d13e-4dfb-a8df-161651159fc5',
#    u'size': u'1417339207',
#    u'state': u'active',
#    u'unique_identifier': u'',
#    u'url': u'ftp://ftp.asc-csa.gc.ca/users/OpenData_DonneesOuvertes/pub/STRATOS%202018/CDH_tm_processed.txt',
#    u'url_type': None}],
#  u'restrictions': u'unrestricted',
#  u'revision_id': u'8b8282b5-d13e-4dfb-a8df-161651159fc5',
#  u'spatial': u'',
#  u'spatial_representation_type': [],
#  u'state': u'active',
#  u'subject': [u'science_and_technology'],
#  u'tags': [],
#  u'title': u'Strato-Science 2018 campaign - Stratospheric Balloon Flight - Canadian Space Agency (CSA) Stratos Telemetry Subsystem',
#  u'title_translated': {u'en': u'Strato-Science 2018 campaign - Stratospheric Balloon Flight - Canadian Space Agency (CSA) Stratos Telemetry Subsystem',
#   u'fr': u'Campagne Strato-Science 2018 - Vol de ballons stratosph\xe9riques - Donn\xe9es des sous-syst\xe8mes de t\xe9l\xe9m\xe9trie de l\u2019Agence spatiale canadienne (ASC)'},
#  u'topic_category': [],
#  u'type': u'dataset',
#  u'url': None,
#  u'version': None}

# %%
delete_keys = [u'creator_user_id', u'groups', u'id', u'revision_id',
               u'isopen', u'license_title', u'license_url', u'metadata_contact', u'metadata_created', 
               u'metadata_modified', u'num_resources', u'owner_org', u'num_tags', u'organization']

resource_delete_keys = [u'datastore_active', u'id', u'package_id', u'position', u'url_type']

cleaned_datasets = []

for dataset in datasets:
    dataset = dataset[u'result']
    
    for key in delete_keys:
        dataset.pop(key, None)

    for resource in dataset[u'resources']:
        for key in resource_delete_keys:
            resource.pop(key, None)

    dataset[u'owner_org'] = u'csa'
    dataset[u'type'] = u'dataset'
    
    cleaned_datasets.append(dataset)

# %%
with open('gov_canada_datasets_clean.json', 'w') as f:
    json.dump(cleaned_datasets, f)

# %%
test_dataset = {
    'collection': 'publication',
    'title_translated': {
        'en': 'englishtiiitlle',
        'fr': 'frtiiiitle'
    },
    'name': 'simplemath',
    'owner_org': 'csa',
    'contributor': {
        'fr': '',
        'en': ''
    },
    'notes_translated': {
        'en': 'ENGLISH NOTES',
        'fr': 'FREEENCH NOTES'
    },
    'keywords': {
        'fr': [
            'Agence spatiale canadienne',
            'ASC',
            'Rendement',
            'Programme spatial canadien',
            'États financiers'
        ],
        'en': [
            'Canadian Space Agency',
            'CSA',
            'Performance management',
            'Canadian Space Program',
            'Financial statements'
        ]
    },
    
    'subject': [
        'economics_and_industry',
        'government_and_politics'
    ],
    'license_id': 'ca-ogl-lgo',
    'audience': [
        'general_public',
        'government',
        'media'
    ],
    
    'place_of_publication': [
        '2458'
    ],
    'imso_approval': 'true',
    'restrictions': 'unrestricted',
    'jurisdiction': 'federal',
    'ready_to_publish': 'true',
    'portal_release_date': '2017-03-14',
    'time_period_coverage_start': '2015-04-01 00:00:00',
    'time_period_coverage_end': '2016-03-31 00:00:00',
    'frequency': 'not_planned',
    'date_published': '2016-11-21 00:00:00',
    'version':  '1.0',
    'language_support': 'english',
    'language_support_specify': 'No French',
    'data_steward': 'Cooper Ang',
    'manager_or_supervisor': 'Manager',
    'diids_no': 'OD1231343',
    'directorate': 'communications',
    'dataset_status': 'completed_form_od',
    'division': 'expl_space_exploration_development',
    'data_owner': 'csa',
    'data_owner_specify': 'none',
    'security_classification': 'protected_a',
    'registered_on_open_data_site': 'True',
    'data_publicly_availible_within_another_site': 'False',
    'eligible_for_release': 'True',
    'format_of_source_data_details': 'xls fs',
    'format_of_source_data': 'xls',
    'size': '340'
}
